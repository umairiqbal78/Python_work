# %%
bill = []
orders = []



ask = input("Welcome to Foodies Mania!\nDo you want to eat something?\nYES or NO ").upper()

#Menu showing
if ask == "YES":
    dishes = {"Cheese burger": 200,"Zinger Burger":400,"Cheese Pizza ":450,"French Fries ":90}
    print("\n\tMENU\nDishes         Price")
    for keys,values in dishes.items():
        print("{:1}{:8}".format(keys,values))
    i =1
    print("\n\tINSTRUCTIONS")
    for keys,items in dishes.items():
        print(f"Press {i} for {keys}")
        i = i+1
    print(f"Press 5 for quit purchasing")   
    
#Order placing
    def Order():
        while ask == "YES":
            ask1 = input("\nPlease Order...")

    #for cheese burgers
            if ask1 == "1":
                ask2 = int(input("How many Cheese Burgers? "))
                def cheese_burger():
                    bill = ask2*dishes["Cheese burger"]
                    return bill

                cheese_burger()
                order = (f"{ask2}X cheese burgers = {cheese_burger()}")
                orders.append(order)
                print(f"{ask2}X cheese burger")
                bill.append(cheese_burger())

    #for Zinger burgers       
            elif ask1 == "2":
                ask2 = int(input("How many Zinger Burgers? "))
                def zinger_burger():
                    bill = ask2*dishes["Zinger Burger"]
                    return bill
                zinger_burger()
                order = (f"{ask2}X zinger burgers = {zinger_burger()}")
                orders.append(order)
                print(f"{ask2}X Zinger Burgers")
                bill.append(zinger_burger())


    #for cheese pizza
            elif ask1 == "3":
                ask2 = int(input("How many Cheese Pizza? "))
                def cheese_pizza():
                    bill = ask2*dishes["Cheese Pizza "]
                    return bill
                cheese_pizza()
                order = (f"{ask2}X cheese pizza = {cheese_pizza()}")
                orders.append(order)
                print(f"{ask2}X Cheese Pizza")
                bill.append(cheese_pizza())


    #for french fries           
            elif ask1 == "4":
                ask2 = int(input("How many French Fries? "))
                def french_fries():
                    bill = ask2*dishes["French Fries "]
                    return bill
                french_fries()
                order = (f"{ask2}X french fries = {french_fries()}")
                orders.append(order)
                print(f"you have ordered {ask2}X French Fries")
                bill.append(french_fries())

    #for ending orders           
            elif ask1 == "5" or "NO":
                print("OK That's all is your order")
                break

    #for handling the wrong entry from user       
            else:
                print("wrong entry")
                break
        
    
        
    #for user to see his orders:
        print(f"\nSir your order is")
        for i in orders:
            print(i)
        total = sum(bill)
        GST = (total/100)*13
        total_bill = int(total + GST)
        print(f"total bill ={total_bill}")

        confirm = input("Please confirm your order, sir. do you want to place this order? YES or NO\n").upper()
        if confirm == "YES":
            name = input("what is your name? ").upper()        
    #SLip
            total = sum(bill)
            GST = (total/100)*13
            total_bill = int(total + GST)
            print(f"\n{name} your order is")
            for i in orders:
                print(i)
            print(f"GST amount is {GST}")
            print(f"Your total bill = Rs.{total_bill} \n\nThank you! Please visit us again :)\nEnjoy your Meal <3")
            from datetime import datetime
            d = datetime.now()
            date = d.strftime("%a, %B %d %Y \n%I:%M:%S %p")
            print(date)
        
        elif confirm == "NO":
            Order()
        return
    Order()     
        

else:
    print(f"Thank you Sir!,Please come again")
# Out:
# Welcome to Foodies Mania!
# Do you want to eat something?
# YES or NO yes
#
# 	MENU
# Dishes         Price
# Cheese burger     200
# Zinger Burger     400
# Cheese Pizza      450
# French Fries       90
#
# 	INSTRUCTIONS
# Press 1 for Cheese burger
# Press 2 for Zinger Burger
# Press 3 for Cheese Pizza
# Press 4 for French Fries
# Press 5 for quit purchasing
#
# Please Order...2
# How many Zinger Burgers? 4
# 4X Zinger Burgers
#
# Please Order...3
# How many Cheese Pizza? 5
# 5X Cheese Pizza
#
# Please Order...3
# How many Cheese Pizza? 4
# 4X Cheese Pizza
#
# Please Order...4
# How many French Fries? 4
# you have ordered 4X French Fries
#
# Please Order...4
# How many French Fries? 4
# you have ordered 4X French Fries
#
# Please Order...5
# OK That's all is your order
#
# Sir your order is
# 4X zinger burgers = 1600
# 5X cheese pizza = 2250
# 4X cheese pizza = 1800
# 4X french fries = 360
# 4X french fries = 360
# total bill =7198
# ...
